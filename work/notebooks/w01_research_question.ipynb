# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Freestyle - AI Referral Opportunity.
# Why: Analyzing AI-referred traffic bridges the gap between traditional SEO and new LLM-based search engines. The goal is to understand which content structures (FAQs, clear definitions, depth) are naturally favored and cited by AI systems to guide optimization strategies.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Question: What content patterns attract AI referral traffic, and which existing pages should be prioritized for AI-visibility optimization? Decision: Identify if a page has the potential to attract AI citations or if it should be left as is. Action: Update the page by restructuring the content (e.g., adding FAQ blocks, clarifying sources, formatting definitions). Cost of a wrong call: Wasting editorial time reformatting pages that have no chance of being cited by AI, while ignoring pages that are on the verge of triggering AI traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import os

if not os.path.exists("data/raw/content_refresh_anonymized.csv"):
    os.makedirs("data/raw", exist_ok=True)
    # !git clone --depth 1 https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
    # !cp flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv data/raw/

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")


total_pages = len(df)
pages_with_ai = len(df[df["ai_sessions_90d"] > 0])
max_ai_sessions = df["ai_sessions_90d"].max()


print(f"Total pages analyzed: {total_pages}")
print(f"Pages with at least 1 AI-referred session: {pages_with_ai} ({pages_with_ai/total_pages:.2%})")
print(f"Maximum AI sessions for a single page: {max_ai_sessions}")
print("\nConclusion for framing: The positive examples are extremely sparse. This confirms we must treat this as an EDA and ranking problem.")
# Out:
# Total pages analyzed: 30000
# Pages with at least 1 AI-referred session: 1930 (6.43%)
# Maximum AI sessions for a single page: 64
#
# Conclusion for framing: The positive examples are extremely sparse. This confirms we must treat this as an EDA and ranking problem.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# Careful words: what I can and can't claim
#
# What I can claim: I can identify directional correlations (e.g., pages with a certain structure receive more clicks from AI tools). I can recommend a prioritized queue for editorial testing based on these observed patterns.
#
# What I can't claim: I cannot claim to have discovered the AI ranking algorithm. I am only measuring sessions where a user actually clicked through from an AI tool, not the overall AI ranking of the page. I also cannot guarantee causal proof that formatting changes will instantly generate AI traffic.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
